# %%
import pandas as pd

# %%
df = pd.read_csv('boat.csv')
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.iloc[10:20]
# Out:
#     Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 10          10         1       3  female   4.0      1      1  16.7000
# 11          11         1       1  female  58.0      0      0  26.5500
# 12          12         0       3    male  20.0      0      0   8.0500
# 13          13         0       3    male  39.0      1      5  31.2750
# 14          14         0       3  female  14.0      0      0   7.8542
# 15          15         1       2  female  55.0      0      0  16.0000
# 16          16         0       3    male   2.0      4      1  29.1250
# 17          17         1       2    male   NaN      0      0  13.0000
# 18          18         0       3  female  31.0      1      0  18.0000
# 19          19         1       3  female   NaN      0      0   7.2250
#
#    embarked   class    who  adult_male deck  embark_town alive  alone
# 10        S   Third  child       False    G  Southampton   yes  False
# ...

# %%
df.iloc[:, [1, 2, 5]]
# Out:
#      survived  pclass  sibsp
# 0           0       3      1
# 1           1       1      1
# 2           1       3      0
# 3           1       1      1
# 4           0       3      0
# ..        ...     ...    ...
# 886         0       2      0
# 887         1       1      0
# 888         0       3      1
# 889         1       1      0
# 890         0       3      0
#
# [891 rows x 3 columns]

# %%
df.iat[1, 2]
# Out:
# 1

# %%
df.at[6, 'age']
# Out:
# 54.0

# %%
df.loc[:, 'age':'fare']
# Out:
#       age  sibsp  parch     fare
# 0    22.0      1      0   7.2500
# 1    38.0      1      0  71.2833
# 2    26.0      0      0   7.9250
# 3    35.0      1      0  53.1000
# 4    35.0      0      0   8.0500
# ..    ...    ...    ...      ...
# 886  27.0      0      0  13.0000
# 887  19.0      0      0  30.0000
# 888   NaN      1      2  23.4500
# 889  26.0      0      0  30.0000
# 890  32.0      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
df['age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %%
df.shape
# Out:
# (891, 16)

# %%
df['class'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
# ...

# %%
df.dropna()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 1             1         1       1  female  38.0      1      0  71.2833
# 3             3         1       1  female  35.0      1      0  53.1000
# 6             6         0       1    male  54.0      0      0  51.8625
# 10           10         1       3  female   4.0      1      1  16.7000
# 11           11         1       1  female  58.0      0      0  26.5500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 871         871         1       1  female  47.0      1      1  52.5542
# 872         872         0       1    male  33.0      0      0   5.0000
# 879         879         1       1  female  56.0      0      1  83.1583
# 887         887         1       1  female  19.0      0      0  30.0000
# 889         889         1       1    male  26.0      0      0  30.0000
#
#     embarked  class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.fillna(15)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female  15.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x='sex',y='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='class'>

# %%
df.expanding()
# Out:
# Expanding [min_periods=1,center=False,axis=0,method=single]

# %%
df.nlargest(10, 'age')
# Out:
#      Unnamed: 0  survived  pclass   sex   age  sibsp  parch     fare embarked  \
# 630         630         1       1  male  80.0      0      0  30.0000        S
# 851         851         0       3  male  74.0      0      0   7.7750        S
# 96           96         0       1  male  71.0      0      0  34.6542        C
# 493         493         0       1  male  71.0      0      0  49.5042        C
# 116         116         0       3  male  70.5      0      0   7.7500        Q
# 672         672         0       2  male  70.0      0      0  10.5000        S
# 745         745         0       1  male  70.0      1      1  71.0000        S
# 33           33         0       2  male  66.0      0      0  10.5000        S
# 54           54         0       1  male  65.0      0      1  61.9792        C
# 280         280         0       3  male  65.0      0      0   7.7500        Q
#
#       class  who  adult_male deck  embark_town alive  alone
# ...

# %%
df.nsmallest(5, 'age')
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 803         803         1       3    male  0.42      0      1   8.5167
# 755         755         1       2    male  0.67      1      1  14.5000
# 469         469         1       3  female  0.75      2      1  19.2583
# 644         644         1       3  female  0.75      2      1  19.2583
# 78           78         1       2    male  0.83      0      2  29.0000
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# 803        C   Third  child       False  NaN    Cherbourg   yes  False
# 755        S  Second  child       False  NaN  Southampton   yes  False
# 469        C   Third  child       False  NaN    Cherbourg   yes  False
# 644        C   Third  child       False  NaN    Cherbourg   yes  False
# 78         S  Second  child       False  NaN  Southampton   yes  False

# %%
df.groupby(by="age")

# %%
df.assign(Area=lambda df: df.alone*df.alive)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone Area
# ...

# %%
pd.qcut(df.age, 20, labels=False)
# Out:
# 0       5.0
# 1      14.0
# 2       8.0
# 3      13.0
# 4      13.0
#        ...
# 886     8.0
# 887     3.0
# 888     NaN
# 889     8.0
# 890    12.0
# Name: age, Length: 891, dtype: float64

# %%
pd.merge(df, df,how='left', on='age')
# Out:
#        Unnamed: 0_x  survived_x  pclass_x sex_x   age  sibsp_x  parch_x  \
# 0                 0           0         3  male  22.0        1        0
# 1                 0           0         3  male  22.0        1        0
# 2                 0           0         3  male  22.0        1        0
# 3                 0           0         3  male  22.0        1        0
# 4                 0           0         3  male  22.0        1        0
# ...             ...         ...       ...   ...   ...      ...      ...
# 42516           890           0         3  male  32.0        0        0
# 42517           890           0         3  male  32.0        0        0
# 42518           890           0         3  male  32.0        0        0
# 42519           890           0         3  male  32.0        0        0
# 42520           890           0         3  male  32.0        0        0
#
#        fare_x embarked_x class_x  ... parch_y   fare_y embarked_y class_y  \
# ...

# %%
pd.merge(df, df,how='right', on='age')
# Out:
#        Unnamed: 0_x  survived_x  pclass_x   sex_x   age  sibsp_x  parch_x  \
# 0                 0           0         3    male  22.0        1        0
# 1                60           0         3    male  22.0        0        0
# 2                80           0         3    male  22.0        0        0
# 3               112           0         3    male  22.0        0        0
# 4               141           1         3  female  22.0        0        0
# ...             ...         ...       ...     ...   ...      ...      ...
# 42516           657           0         3  female  32.0        1        1
# 42517           665           0         2    male  32.0        2        0
# 42518           769           0         3    male  32.0        0        0
# 42519           838           1         3    male  32.0        0        0
# 42520           890           0         3    male  32.0        0        0
#
#         fare_x embarked_x class_x  ... parch_y  fare_y embarked_y class_y  \
# ...

# %%
pd.merge(df, df,how='inner', on='class')
# Out:
#         Unnamed: 0_x  survived_x  pclass_x sex_x  age_x  sibsp_x  parch_x  \
# 0                  0           0         3  male   22.0        1        0
# 1                  0           0         3  male   22.0        1        0
# 2                  0           0         3  male   22.0        1        0
# 3                  0           0         3  male   22.0        1        0
# 4                  0           0         3  male   22.0        1        0
# ...              ...         ...       ...   ...    ...      ...      ...
# 321588           886           0         2  male   27.0        0        0
# 321589           886           0         2  male   27.0        0        0
# 321590           886           0         2  male   27.0        0        0
# 321591           886           0         2  male   27.0        0        0
# 321592           886           0         2  male   27.0        0        0
#
#         fare_x embarked_x   class  ... sibsp_y  parch_y   fare_y embarked_y  \
# ...

# %%
pd.merge(df, df,how='outer', on='class')
# Out:
#         Unnamed: 0_x  survived_x  pclass_x sex_x  age_x  sibsp_x  parch_x  \
# 0                  0           0         3  male   22.0        1        0
# 1                  0           0         3  male   22.0        1        0
# 2                  0           0         3  male   22.0        1        0
# 3                  0           0         3  male   22.0        1        0
# 4                  0           0         3  male   22.0        1        0
# ...              ...         ...       ...   ...    ...      ...      ...
# 321588           886           0         2  male   27.0        0        0
# 321589           886           0         2  male   27.0        0        0
# 321590           886           0         2  male   27.0        0        0
# 321591           886           0         2  male   27.0        0        0
# 321592           886           0         2  male   27.0        0        0
#
#         fare_x embarked_x   class  ... sibsp_y  parch_y   fare_y embarked_y  \
# ...
