# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 4*np.pi,1000)
y = np.sin(x)

# %%
fig,ax = plt.subplots()
ax.plot(x,y)
fig.show
# Out:
# <bound method Figure.show of <Figure size 432x288 with 1 Axes>>

# %%
x = np.random.uniform(0,1,100)
y = np.random.uniform(0,1,100)
plt.scatter(x,y)

# %%
x = np.arange(10)
y = np.random.uniform(1,10,10)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
z = np.random.uniform(0,1,(8,8))
plt.imshow(z)

# %%
z = np.random.uniform(0,1,(8,8))
plt.contourf(z)

# %%
z=np.random.uniform(0,1,4)
plt.hist(z)
# Out:
# (array([1., 0., 0., 0., 0., 0., 1., 0., 0., 2.]),
#  array([0.07797843, 0.16996657, 0.2619547 , 0.35394283, 0.44593096,
#         0.5379191 , 0.62990723, 0.72189536, 0.8138835 , 0.90587163,
#         0.99785976]),
#  <BarContainer object of 10 artists>)

# %%
x=np.arange(5)
y=np.random.uniform(0,1,5)
plt.errorbar(x,y,y/4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
z=np.random.normal(0,1,(100,3))
plt.boxplot(z)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ff6105ea60>,
#   <matplotlib.lines.Line2D at 0x1ff6105edf0>,
#   <matplotlib.lines.Line2D at 0x1ff60ef33d0>,
#   <matplotlib.lines.Line2D at 0x1ff60ef3760>,
#   <matplotlib.lines.Line2D at 0x1ff60ee6d00>,
#   <matplotlib.lines.Line2D at 0x1ff60ed70d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ff60ee21c0>,
#   <matplotlib.lines.Line2D at 0x1ff60ee2550>,
#   <matplotlib.lines.Line2D at 0x1ff60ef3af0>,
#   <matplotlib.lines.Line2D at 0x1ff60ef3e80>,
#   <matplotlib.lines.Line2D at 0x1ff60ed7460>,
#   <matplotlib.lines.Line2D at 0x1ff60ed77f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ff6105e6d0>,
#   <matplotlib.lines.Line2D at 0x1ff60ef3040>,
#   <matplotlib.lines.Line2D at 0x1ff60ee6970>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ff60ee28e0>,
#   <matplotlib.lines.Line2D at 0x1ff60ee6250>,
#   <matplotlib.lines.Line2D at 0x1ff60ed7b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ff60ee2c70>,
#   <matplotlib.lines.Line2D at 0x1ff60ee65e0>,
#   <matplotlib.lines.Line2D at 0x1ff60ed7f10>],
#  'means': []}

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
ax.plot(x,y,color="black")

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,linestyle="--")

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,linewidth="5")

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,marker="o")

# %%
x=np.linspace(0,10,100)
y1,y2=np.sin(x),np.cos(x)
plt.plot(x,y1,x,y2)
# Out:
# [<matplotlib.lines.Line2D at 0x1ff6122f5e0>,
#  <matplotlib.lines.Line2D at 0x1ff6122f610>]

# %%
fig, (plt1,plt2) = plt.subplots(2,1)
plt1.plot(x,y1, color = 'C1')
plt2.plot(x,y2, color = 'C0')

# %%
fig, (plt1,plt2) = plt.subplots(2,1)
plt1.plot(y1,x, color = 'C1')
plt2.plot(y2,x, color = 'C0')

# %%
plt.plot(x,y)
fig.suptitle(None)
plt.title("A Sine Wave")
# Out:
# Text(0.5, 1.0, 'A Sine Wave')

# %%
plt.plot(x,y)
plt.ylabel(None)
plt.xlabel("time")
# Out:
# Text(0.5, 0, 'time')

# %%
fig.savefig("my-first-figure.png",dpi=300)
fig.savefig("my-first-figure.pdf")
